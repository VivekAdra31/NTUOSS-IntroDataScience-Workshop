# %% [markdown]
# # Introduction to Data Science
# <img src="images/Logo.png" align=left width=500 height=500></img>

# %% [markdown]
# # What is Data Science?
# 1. ### Have you ever wondered how Amazon, eBay suggest items for you to buy?
# 1. ### How Gmail filters your emails in the spam and non-spam categories?
# 1. ### How Netflix predicts the shows of your liking?
#
# ## Data science is all about using data to solve problems.
# ## So, the core job of a data scientist is to understand the data, extract useful information out of it and apply this in solving the problems.

# %% [markdown]
# <img src="images/Data.png" align=left width=500 height=500></img>
# <img src="images/Fields.png" align=right width=400 height=400></img>

# %% [markdown]
# # Data Science Life Cycle:
# 1. ### Problem Formulation
# 2. ### Data Collection
# 3. ### Data Cleaning/Quality Check
# 4. ### Statistical Description
# 5. ### Exploratory Data Analysis
# 6. ### Machine Learning
# 7. ### Statistical Inference
# 8. ### Decision Making

# %% [markdown]
# <img src="images/AI.png" align=right width=700 height=700></img>

# %% [markdown]
# # Problem Formulation:
# ## Most Data Science problems fall into the following categories:
# - ### Numeric Prediction
# - ### Classification
# - ### Detection of Structure within data(Clustering)
# - ### Anomaly Detection
# - ### Intelligent Decision Making

# %% [markdown]
# # Common Data Types
# ## Two Primary Data Types
# 1. ### Structured Data
#    Highly Organized, Easy to Analyze Numeric/Factor, Time Series, Network
# 2. ### Unstructured Data
# Highly Unorganized and Contextual Text, Image, Voice, Videos

# %% [markdown]
# # Structured Data
#
# 1. ## Numeric Data:
# Numeric Continuous Variables
#
# 1. ## Categorical Data:
# Factor/Level/Class Variables
#
#
# 1. ## TimeSeries Data:
# Numeric Variables with Timestamps
#
# 1. ## Network Data:
# Nodes and Connections

# %% [markdown]
# # Unstructured Data
#
# 1. ## Text Data
#
# 1. ## Image Data
#
#
# 1. ## Video Data
#
#
# 1. ## Audio Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#df = pd.read_csv("winequality-red.csv")
df = pd.read_excel('data/real_estate.xlsx')
#xls_data.head()

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1          2012.916667          32.0
# 1   2          2012.916667          19.5
# 2   3          2013.583333          13.3
# 3   4          2013.500000          13.3
# 4   5          2012.833333           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df = df.drop(columns=['No'])
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0          2012.916667          32.0                                84.87882
# 1          2012.916667          19.5                               306.59470
# 2          2013.583333          13.3                               561.98450
# 3          2013.500000          13.3                               561.98450
# 4          2012.833333           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# ...

# %%
print("Data type : ", type(df))
print("Data dims : ", df.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (414, 7)

# %%
print(df.dtypes)
# Out:
# X1 transaction date                       float64
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   X1 transaction date                     414 non-null    float64
#  1   X2 house age                            414 non-null    float64
#  2   X3 distance to the nearest MRT station  414 non-null    float64
#  3   X4 number of convenience stores         414 non-null    int64
#  4   X5 latitude                             414 non-null    float64
#  5   X6 longitude                            414 non-null    float64
#  6   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 22.8 KB

# %%
df.describe()
# Out:
#        X1 transaction date  X2 house age  \
# count           414.000000    414.000000
# mean           2013.148953     17.712560
# std               0.281995     11.392485
# min            2012.666667      0.000000
# 25%            2012.916667      9.025000
# 50%            2013.166667     16.100000
# 75%            2013.416667     28.150000
# max            2013.583333     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                       414.000000   414.000000    414.000000
# ...

# %%
house_age = pd.DataFrame(df['X2 house age'])

# %% [markdown]
# # Univariate Statistics

# %%
f, axes = plt.subplots(1, 1, figsize=(24, 4))
sb.boxplot(house_age, orient = "h")

# %%
f, axes = plt.subplots(1, 1, figsize=(24, 12))
sb.distplot(house_age, kde = False, color = "red")

# %%
f, axes = plt.subplots(1, 1, figsize=(24, 12))
sb.distplot(house_age, hist = False, color = "red")

# %%
f, axes = plt.subplots(1, 1, figsize=(24, 12))
sb.distplot(house_age, color = "red")

# %% [markdown]
# # Feature Engineering:
# Feature engineering is the process of using domain knowledge to extract features from raw data via data mining techniques. These features can be used to improve the performance of machine learning algorithms.

# %%
df['X8 transaction year'] = df['X1 transaction date']-df['X1 transaction date']%1
df['X7 transaction month'] = df['X1 transaction date']%1*12
df['X7 transaction month'] = df['X7 transaction month'].astype(int)
df['X8 transaction year']= df['X8 transaction year'].astype(int)

# %%
df
# Out:
#      X1 transaction date  X2 house age  \
# 0            2012.916667          32.0
# 1            2012.916667          19.5
# 2            2013.583333          13.3
# 3            2013.500000          13.3
# 4            2012.833333           5.0
# ..                   ...           ...
# 409          2013.000000          13.7
# 410          2012.666667           5.6
# 411          2013.250000          18.8
# 412          2013.000000           8.1
# 413          2013.500000           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ...

# %% [markdown]
# # Multivariate Statistics

# %%
#Classes in Number of Convenience Store
print("Number of Classes:", len(df["X4 number of convenience stores"].unique()))

# Count for number of Convenience stores
sb.catplot(y = "X4 number of convenience stores", data = df, kind = "count")
# Out:
# Number of Classes: 11

# %%
f, axes = plt.subplots(9, 3, figsize=(30, 30))

count = 0
for var in df:
    sb.boxplot(df[var], orient = "h", ax = axes[count,0])
    sb.distplot(df[var], ax = axes[count,1])
    sb.violinplot(df[var], ax = axes[count,2])
    count += 1

# %%
f, axes = plt.subplots(1, 1, figsize=(12, 8))
sb.heatmap(df.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")

# %% [markdown]
# ## Regression

# %%
# Extract Response and Predictors
y = pd.DataFrame(df["Y house price of unit area"])
X = df.drop(columns=['Y house price of unit area'])

# %%
# Import train_test_split from sklearn
from sklearn.model_selection import train_test_split

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", y_train.shape, X_train.shape)
print("Test Set  :", y_test.shape, X_test.shape)
# Out:
# Train Set : (310, 1) (310, 8)
# Test Set  : (104, 1) (104, 8)

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression


# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Print the Coefficients against Predictors
pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"])
# Out:
# Intercept of Regression 	: b =  [-8502.3648386]
# Coefficients of Regression 	: a =  [[ 2.00019012e+01 -2.21193772e-01 -4.65955456e-03  1.19335372e+00
#    2.09373898e+02 -2.26496326e+01 -1.69869045e+01 -1.56709028e+00]]
#                                Predictors  Coefficients
# 0                     X1 transaction date     20.001901
# 1                            X2 house age     -0.221194
# 2  X3 distance to the nearest MRT station     -0.004660
# 3         X4 number of convenience stores      1.193354
# 4                             X5 latitude    209.373898
# 5                            X6 longitude    -22.649633
# 6                     X8 transaction year    -16.986904
# 7                    X7 transaction month     -1.567090

# %%
# Predict the Total values from Predictors
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'r', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'r', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %%
# Import mean_squared_error from sklearn
from sklearn.metrics import mean_squared_error

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.5318274517978254
# Mean Squared Error (MSE) 	: 84.38301592984757
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.707293876407932
# Mean Squared Error (MSE) 	: 56.00486553787694
